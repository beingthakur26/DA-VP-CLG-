# %%
import numpy as np

li = [1, 2, 3, 4, 5, 6, 7, 8]

np.mean(li)
# Out:
# np.float64(4.5)

# %%
a=np.median(li)
print(a)
# Out:
# 4.5

# %%
print(np.mean(li))
# Out:
# 4.5

# %%
import statistics as stat
b = stat.variance(li)
print(b)
# Out:
# 6

# %%
# import matplotlib.pyplot as mtb
# x = [1, 2, 3, 4, 5]
# y = [10, 15, 20, 25, 30]
# mtb.bar(x, y, color='pink')
# mtb.show()

# %%
# import matplotlib.pyplot as plt

# x = [7, 8, 9, 10, 10, 12, 12, 12, 13, 14, 14, 15, 16, 16, 17, 18, 18, 19, 20, 20,
#      21, 22, 23, 24, 25, 25, 26, 28, 30, 32, 35, 36, 38, 40, 42, 44, 48, 50]

# plt.hist(x, bins=10, color='green')
# plt.title("Histogram")
# plt.xlabel("Total Bill")
# plt.ylabel("Frequency")
# # plt.show()

# %%
# import matplotlib.pyplot as mtb
# x = [1, 2, 3, 4, 5]
# y = [10, 15, 20, 25, 30]
# mtb.scatter(x,y)
# mtb.show()

# %%
# import matplotlib.pyplot as plt

# data = [ [10, 12, 14, 15, 18, 20, 22],
#          [8, 9, 11, 13, 17, 19, 21],
#          [14, 16, 18, 20, 23, 25, 27] ]

# plt.boxplot(data)
# # plt.xlabel("Groups")
# # plt.ylabel("Values")
# plt.title("Box Plot")
# plt.show()

# %%
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as mtb

dic = {
    "name": "manas singh",
    "marks": [40, 50, 60],
    "subject": ["Maths", "Science", "Physics"]
}

df = pd.DataFrame(dic)
# sea.barplot(x="marks", y="subject", data=df)
# sea.lineplot(x="marks", y="subject", data=df)
# sea.relplot(x="marks", y="subject", data=df)
# sea.scatterplot(x="marks", y="subject", data=df)
# sea.boxplot(x="marks", y="subject", data=df)
sea.violinplot(x="marks", y="subject", data=df)
mtb.show()
