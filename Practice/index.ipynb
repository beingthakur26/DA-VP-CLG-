# %%
a = 25
print(a)
# Out:
# 25

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


dic = {
    "marks": [40, 50, 60],
    "subject": ["Maths", "Science", "Physics"]
}

df = pd.DataFrame(dic)
sns.barplot(x="subject", y="marks", data=df)
# sns.lineplot(x="marks", y="subject", data=df)
# sns.relplot(x="marks", y="subject", data=df)
# sns.scatterplot(x="marks", y="subject", data=df)
# sns.boxplot(x="marks", y="subject", data=df)
# sns.violinplot(x="marks", y="subject", data=df)
plt.show()
